# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas_profiling import ProfileReport

# %%
dataset=pd.read_csv("dataminerocks.csv")
dataset.head(5)
# Out:
#    Unnamed: 0  attribute_1  attribute_2  attribute_3  attribute_4  \
# 0           1       0.0200       0.0371       0.0428       0.0207
# 1           2       0.0453       0.0523       0.0843       0.0689
# 2           3       0.0262       0.0582       0.1099       0.1083
# 3           4       0.0100       0.0171       0.0623       0.0205
# 4           5       0.0762       0.0666       0.0481       0.0394
#
#    attribute_5  attribute_6  attribute_7  attribute_8  attribute_9  ...  \
# 0       0.0954       0.0986       0.1539       0.1601       0.3109  ...
# 1       0.1183       0.2583       0.2156       0.3481       0.3337  ...
# 2       0.0974       0.2280       0.2431       0.3771       0.5598  ...
# 3       0.0205       0.0368       0.1098       0.1276       0.0598  ...
# 4       0.0590       0.0649       0.1209       0.2467       0.3564  ...
#
#    attribute_52  attribute_53  attribute_54  attribute_55  attribute_56  \
# ...

# %% [markdown]
# ### Encoding response variable (y)

# %%
# Encoding dependent variable using label encoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
dataset["Class"]=le.fit_transform(dataset["Class"])
print(dataset["Class"])
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 203    0
# 204    0
# 205    0
# 206    0
# 207    0
# Name: Class, Length: 208, dtype: int64

# %%
dataset.head(5)
# Out:
#    Unnamed: 0  attribute_1  attribute_2  attribute_3  attribute_4  \
# 0           1       0.0200       0.0371       0.0428       0.0207
# 1           2       0.0453       0.0523       0.0843       0.0689
# 2           3       0.0262       0.0582       0.1099       0.1083
# 3           4       0.0100       0.0171       0.0623       0.0205
# 4           5       0.0762       0.0666       0.0481       0.0394
#
#    attribute_5  attribute_6  attribute_7  attribute_8  attribute_9  ...  \
# 0       0.0954       0.0986       0.1539       0.1601       0.3109  ...
# 1       0.1183       0.2583       0.2156       0.3481       0.3337  ...
# 2       0.0974       0.2280       0.2431       0.3771       0.5598  ...
# 3       0.0205       0.0368       0.1098       0.1276       0.0598  ...
# 4       0.0590       0.0649       0.1209       0.2467       0.3564  ...
#
#    attribute_52  attribute_53  attribute_54  attribute_55  attribute_56  \
# ...

# %% [markdown]
# ### Data summary

# %%
dataset.describe()
# Out:
#        Unnamed: 0  attribute_1  attribute_2  attribute_3  attribute_4  \
# count  208.000000   208.000000   208.000000   208.000000   208.000000
# mean   104.500000     0.029164     0.038437     0.043832     0.053892
# std     60.188592     0.022991     0.032960     0.038428     0.046528
# min      1.000000     0.001500     0.000600     0.001500     0.005800
# 25%     52.750000     0.013350     0.016450     0.018950     0.024375
# 50%    104.500000     0.022800     0.030800     0.034300     0.044050
# 75%    156.250000     0.035550     0.047950     0.057950     0.064500
# max    208.000000     0.137100     0.233900     0.305900     0.426400
#
#        attribute_5  attribute_6  attribute_7  attribute_8  attribute_9  ...  \
# count   208.000000   208.000000   208.000000   208.000000   208.000000  ...
# mean      0.075202     0.104570     0.121747     0.134799     0.178003  ...
# std       0.055552     0.059105     0.061788     0.085152     0.118387  ...
# ...

# %% [markdown]
# ### Pandas Profiler

# %%
# design_report = ProfileReport(dataset)
# design_report.to_file(output_file='EDA_Sonar_Data.html')

# %% [markdown]
# ### Sweetviz EDA

# %%
import sweetviz as sv
sweet_report = sv.analyze(dataset)
sweet_report.show_html('sweet_Sonar_Data.html')
# Out:
# ...
# Report sweet_Sonar_Data.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
